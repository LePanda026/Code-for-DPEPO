# %%
from env_manager_parallel import build_parallel_alfworld_envs

# %%
import json

data = json.load(open('/data/home/zhangjs/disk/project/verl-agent/data_pipelines/gamefiles/gamefiles_train.json','r'))

gamefiles = list(data.values())

# %%
parallel_env = build_parallel_alfworld_envs(gamefiles=gamefiles[:1],
                                            # env_num=512,
                                            group_n=1,
                                            resources_per_worker={'num_cpus': 0.5},
                                            num_parallel=1)

# %%
parallel_env.reset()

# %%
group_parallel_data = [ 
    {'uuid':'1','group_id':0,'action':{1:'1',2:'1',3:'1'},'action_dict':{1:'1',2:'1',3:'1'},'gamefile':gamefiles[0]},
]

# %%
start_info = parallel_env.get_start_info_group(group_parallel_data) 
start_info

# %%
history_info1 = parallel_env.get_history_info_group(group_parallel_data) 
last_action1 = parallel_env.get_last_actions_info_group(group_parallel_data) 
history_info1, last_action1

# %%
last_action1

# %%
group_parallel_data

# %%
output = parallel_env.step_group(group_parallel_data)

# %%
from verl.utils.dataset.rl_dataset import collate_fn 

cancanneed = collate_fn(output)

cancanneed

# %%
history_info1 = parallel_env.get_history_info_group(group_parallel_data) 
last_action1 = parallel_env.get_last_actions_info_group(group_parallel_data) 
last_action1

# %%
cancanneed['rewards']

# %%
import numpy as np

row_sums = np.sum(cancanneed['rewards'], axis=1)
row_sums

# %%
history_info2 = parallel_env.get_history_info_group(group_parallel_data) 
last_action2 = parallel_env.get_last_actions_info_group(group_parallel_data) 
history_info2,last_action2

# %%
group_parallel_data = [
    {'uuid':'1','group_id':0,'action':{1:'1',2:'5'},'gamefile':gamefiles[0]},
    {'uuid':'1','group_id':1,'action':{1:'1',2:'6'},'gamefile':gamefiles[0]},
    {'uuid':'1','group_id':2,'action':{1:'1',2:'7'},'gamefile':gamefiles[0]},
    {'uuid':'1','group_id':3,'action':{1:'1',2:'8'},'gamefile':gamefiles[0]},
    {'uuid':'2','group_id':0,'action':{1:'1',2:'5'},'gamefile':gamefiles[1]},
    {'uuid':'2','group_id':1,'action':{1:'1',2:'6'},'gamefile':gamefiles[1]},
    {'uuid':'2','group_id':2,'action':{1:'1',2:'7'},'gamefile':gamefiles[1]},
    {'uuid':'2','group_id':3,'action':{1:'1',2:'8'},'gamefile':gamefiles[1]},
]

# %%
output = parallel_env.step_group(group_parallel_data) 
output[0]

# %%
history_info3 = parallel_env.get_history_info_group(group_parallel_data) 
last_action3 = parallel_env.get_last_actions_info_group(group_parallel_data) 
history_info3, last_action3

# %%
group_parallel_data = [
    {'uuid':'1','group_id':0,'action':{1:'1',2:'11'},'gamefile':gamefiles[0]},
    {'uuid':'1','group_id':1,'action':{1:'1',2:'22'},'gamefile':gamefiles[0]},
    {'uuid':'1','group_id':2,'action':{1:'1',2:'33'},'gamefile':gamefiles[0]},
    {'uuid':'1','group_id':3,'action':{1:'1',2:'44'},'gamefile':gamefiles[0]},
    {'uuid':'2','group_id':0,'action':{1:'1',2:'11'},'gamefile':gamefiles[1]},
    {'uuid':'2','group_id':1,'action':{1:'1',2:'22'},'gamefile':gamefiles[1]},
    {'uuid':'2','group_id':2,'action':{1:'1',2:'33'},'gamefile':gamefiles[1]},
    {'uuid':'2','group_id':3,'action':{1:'1',2:'44'},'gamefile':gamefiles[1]},
]

# %%
output = parallel_env.step_group(group_parallel_data) 
output[0]

history_info3 = parallel_env.get_history_info_group(group_parallel_data) 
last_action3 = parallel_env.get_last_actions_info_group(group_parallel_data) 
history_info3, last_action3
