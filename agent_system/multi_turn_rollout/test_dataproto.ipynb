# %%
import torch
import numpy as np
from verl import DataProto
from verl.utils.dataset.rl_dataset import collate_fn

test_data = [
    {'input_ids':torch.randn((1,2048)),'gamefile':'111.json'},
    {'input_ids':torch.randn((1,2048)),'gamefile':'111.json'},
]

batch = DataProto.from_single_dict(
    collate_fn(test_data)
)

batch
# Out:
# DataProto(batch=TensorDict(
#     fields={
#         input_ids: Tensor(shape=torch.Size([2, 1, 2048]), device=cpu, dtype=torch.float32, is_shared=False)},
#     batch_size=torch.Size([2]),
#     device=None,
#     is_shared=False), non_tensor_batch={'gamefile': array(['111.json', '111.json'], dtype=object)}, meta_info={})

# %%
batch.non_tensor_batch['gamefile'][1]
# Out:
# '111.json'

# %%
# DataProto.from_single_dict(
#             data=collate_fn(effective_batch)
#         )
