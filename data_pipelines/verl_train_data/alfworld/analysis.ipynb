# %%
import pandas as pd

data = pd.read_parquet('dedu_parallel_train_data_500_w_gt.parquet')

# wtf?
len(data)

# %%
data.head(5)

# %%
import numpy as np

outcome_reward = np.array([1, 1, 1, 0, 0, 0, 1])
process_reward = np.array([0.5, 0.6, 0.7, 0.8, 0.7, 0.6, 1])

result = np.where(outcome_reward == 0, process_reward, outcome_reward)
print(result)
# Out:
# [1.  1.  1.  0.8 0.7 0.6 1. ]
# (None, 7)
